# %%
pip install selenium webdriver-manager beautifulsoup4
# Out:
# Requirement already satisfied: selenium in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (4.27.1)
# Collecting webdriver-manager
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: beautifulsoup4 in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (4.11.1)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: trio~=0.17 in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from selenium) (0.27.0)
# Requirement already satisfied: websocket-client~=1.8 in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: typing_extensions~=4.9 in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from selenium) (4.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: packaging in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from webdriver-manager) (24.1)
# Requirement already satisfied: requests in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from webdriver-manager) (2.32.3)
# Requirement already satisfied: python-dotenv in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4) (2.3.1)
# Requirement already satisfied: idna in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: sortedcontainers in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: attrs>=23.2.0 in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: exceptiongroup in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from trio~=0.17->selenium) (1.2.2)
# Requirement already satisfied: wsproto>=0.14 in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/fuaison/opt/anaconda3/lib/python3.9/site-packages (from requests->webdriver-manager) (2.0.4)
# Installing collected packages: webdriver-manager
# Successfully installed webdriver-manager-4.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.firefox.service import Service
from webdriver_manager.firefox import GeckoDriverManager
import time
from bs4 import BeautifulSoup

# setup Firefox WebDriver
options = webdriver.FirefoxOptions()
options.add_argument('--headless')  # 无头模式，避免弹出浏览器界面
options.add_argument('--disable-gpu')  # 禁用GPU加速
options.add_argument('start-maximized')  # 最大化窗口

# 初始化 WebDriver
driver = webdriver.Firefox(service=Service(GeckoDriverManager().install()), options=options)

# 目标网址
url = "https://www.arabidopsis.org/news/jobs"

# 请求网页
driver.get(url)

# 等待页面加载，适当延时
time.sleep(5)  # 根据需要增加等待时间，确保所有动态内容加载完毕

# 获取网页内容
webpage = driver.page_source

# 使用 BeautifulSoup 解析网页
soup = BeautifulSoup(webpage, 'html.parser')

# 查找职位列表
job_list = soup.find_all('div', class_='news-item')

# 确认是否找到了职位数据
if not job_list:
    print("没有找到职位信息，请检查网页结构")
    driver.quit()  # 关闭浏览器
    exit()

# 创建一个列表，用于保存抓取的数据
jobs_data = []

# 遍历职位列表
for job in job_list:
    try:
        # 提取职位标题和链接
        job_title_tag = job.find('div', class_='news-header').find('a')
        job_title = job_title_tag.text.strip() if job_title_tag else 'N/A'

        # 提取职位链接
        job_link = job_title_tag['href'] if job_title_tag else 'N/A'
        job_link = f"https://www.arabidopsis.org{job_link}"  # 补全链接

        # 提取位置（假设位置是下一个 div 标签）
        job_location = job.find('div', class_='news-header').find_next('div').text.strip() if job.find('div', class_='news-header').find_next('div') else 'N/A'

        # 提取申请截止日期（假设截止日期在下一个 div 标签）
        application_deadline = job.find('div', class_='news-header').find_next('div').find_next('div').text.strip() if job.find('div', class_='news-header').find_next('div').find_next('div') else 'N/A'

        # 添加职位信息到 jobs_data 列表
        jobs_data.append([job_title, job_location, application_deadline, job_link])

    except Exception as e:
        print(f"抓取职位时出错: {e}")

# 输出为 CSV 文件
csv_filename = 'job_listings.csv'

# 打开文件并写入数据
with open(csv_filename, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # 写入 CSV 表头
    writer.writerow(['Job Title', 'Location', 'Application Deadline', 'Job Link'])
    
    # 写入每个职位的数据
    for job_data in jobs_data:
        writer.writerow(job_data)

print(f"数据已保存到 {csv_filename}")

# 关闭浏览器
driver.quit()
# Out:
# 数据已保存到 job_listings.csv

# %%
import pandas as pd
data = pd.read_csv("job_listings.csv")
df = pd.DataFrame(data)
df.head()
# Out:
#                                            Job Title  ...                                           Job Link
# 0    Dec 11, 2024, Graduate research assistanship MS  ...  https://www.arabidopsis.org/news/jobs/view?fil...
# 1  Dec 10, 2024, Plant Microbe Interaction Postdo...  ...  https://www.arabidopsis.org/news/jobs/view?fil...
# 2  Dec 10, 2024, PhD positionin Plant Evolutionar...  ...  https://www.arabidopsis.org/news/jobs/view?fil...
# 3  Dec 6, 2024, Master's, Ph.D., and Postdoc Posi...  ...  https://www.arabidopsis.org/news/jobs/view?fil...
# 4  Dec 6, 2024, Technician, stomata, photosynthes...  ...  https://www.arabidopsis.org/news/jobs/view?fil...
#
# [5 rows x 4 columns]
